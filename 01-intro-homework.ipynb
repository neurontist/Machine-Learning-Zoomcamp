# %% [markdown]
# ## Week 1 Homework

# %% [markdown]
# ## Q1. Pandas version
# What's the version of Pandas that you installed?

# %%
import pandas as pd

pd.__version__
# Out:
# '2.3.2'

# %% [markdown]
# ## Getting the data

# %%
car_df = pd.read_csv("https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv")

car_df.head()
# Out:
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                  170            3.0       159.0     3413.433759
# 1                  130            5.0        97.0     3149.664934
# 2                  170            NaN        78.0     3079.038997
# 3                  220            4.0         NaN     2542.392402
# 4                  210            1.0       140.0     3460.870990
#
#    acceleration  model_year  origin fuel_type         drivetrain  num_doors  \
# 0          17.7        2003  Europe  Gasoline    All-wheel drive        0.0
# 1          17.8        2007     USA  Gasoline  Front-wheel drive        0.0
# 2          15.1        2018  Europe  Gasoline  Front-wheel drive        0.0
# 3          20.2        2009     USA    Diesel    All-wheel drive        2.0
# 4          14.4        2009  Europe  Gasoline    All-wheel drive        2.0
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# ...

# %% [markdown]
# ## Q2. Records count
# How many records are in the dataset?

# %%
print("Number of records in the dataset: ", car_df.shape[0])
# Out:
# Number of records in the dataset:  9704

# %% [markdown]
# ## Q3. Fuel types
# How many fuel types are presented in the dataset?

# %%
print("Number of fuel types in the dataset: ", car_df['fuel_type'].nunique())
# Out:
# Number of fuel types in the dataset:  2

# %% [markdown]
# ## Q4. Missing values
# How many columns in the dataset have missing values?

# %%
print("Number of columns with missing values: ", sum(car_df.isna().sum()>0))
# Out:
# Number of columns with missing values:  4

# %% [markdown]
# ## Q5. Max fuel efficiency
# What's the maximum fuel efficiency of cars from Asia?

# %%
max_fuel_eff = car_df.loc[car_df['origin'] == 'Asia', 'fuel_efficiency_mpg'].max().round(2)
print("Maximum fuel efficiency of cars from Asia: ", max_fuel_eff)
# Out:
# Maximum fuel efficiency of cars from Asia:  23.76

# %% [markdown]
# ## Q6. Median value of horsepower
# 1. Find the median value of `horsepower` column in the dataset.
# 2. Next, calculate the most frequent value of the same `horsepower` column.
# 3. Use `fillna` method to fill the missing values in `horsepower` column with the most frequent value from the previous step.
# 4. Now, calculate the median value of `horsepower` once again.
# Has it changed?

# %%
# 1
median_horsepower_before = car_df['horsepower'].median()
print("Median before fillna: ", median_horsepower_before)
# 2
freq_horsepower = car_df['horsepower'].mode()

# 3
car_df['horsepower'] = car_df['horsepower'].fillna(freq_horsepower[0])
car_df.iloc[3]

# 4
median_horsepower_after = car_df['horsepower'].median()
print("Median before fillna: ", median_horsepower_after)
# Out:
# Median before fillna:  149.0
# Median before fillna:  152.0

# %% [markdown]
# #### Answer: Yes, it increased

# %% [markdown]
# ## Q7. Sum of weights
# 1. Select all the cars from Asia
# 2. Select only columns vehicle_weight and model_year
# 3. Select the first 7 values
# 4. Get the underlying NumPy array. Let's call it X.
# 5. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# 6. Invert XTX.
# 7. Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200].
# 8.
# 9. Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result
# 10. What's the sum of all the elements of the result?
# * Note: You just implemented linear regression. We'll talk about it in the next lesson.

# %%
import numpy as np
# 1 
asia_df = car_df[car_df['origin'] == 'Asia']

# 2
vehicle_model_df = asia_df[['vehicle_weight','model_year']]

# 3
first7_val = vehicle_model_df.head(7)

# 4
X = np.array(first7_val)

# 5
XTX = X.T @ X

# 6
inv = np.linalg.inv(XTX)

# 7
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# 8
result = (inv @ X.T) * y

# 9
print(np.sum(result))
# Out:
# 0.5187709081074016
